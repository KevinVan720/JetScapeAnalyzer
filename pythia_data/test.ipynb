# %%
import sys
import math
import itertools
import re
import csv
import pprint
import xml.etree.ElementTree as ET
from collections import OrderedDict
import pickle
import io

GeVfm = 0.19732696312541853
c_speed_of_light = 29.9792458e10  # mm / s
# for nuclear masses
mneutron = 0.9395654133  # GeV
mproton = 0.9382720813  # GeV

namespace = "corsika"

##############################################################
#
# reading xml input data, return line by line particle data
#


def parsePythia(filename):
    tree = ET.parse(filename)
    root = tree.getroot()

    for particle in root.iter("particle"):
        name = particle.attrib["name"]
        antiName = "Unknown"
        if ("antiName" in particle.attrib):
            antiName = particle.attrib["antiName"]
        pdg_id = int(particle.attrib["id"])
        mass = float(particle.attrib["m0"])  # GeV
        electric_charge = int(particle.attrib["chargeType"])  # in units of e/3
        ctau = 0.
        if pdg_id in (11, 12, 14, 16, 22, 2212):  # these are the stable particles !
            ctau = float('Inf')
        elif 'tau0' in particle.attrib:
            ctau = float(particle.attrib['tau0'])  # mm / c
        elif 'mWidth' in particle.attrib:
            ctau = GeVfm / \
                float(particle.attrib['mWidth']) * 1e-15 * 1000.0  # mm / s
        # those are certainly not stable....
        elif pdg_id in (0, 423, 433, 4312, 4322, 5112, 5222):
            ctau = 0.
        else:
            print("missing lifetime: " + str(pdg_id) + " " + str(name))
            sys.exit(1)

        yield (pdg_id, name, mass, electric_charge, antiName, ctau/c_speed_of_light)

        # TODO: read decay channels from child elements

        if "antiName" in particle.attrib:
            yield (-pdg_id, antiName, mass, -electric_charge, name, ctau/c_speed_of_light)


##############################################################
#
# reading xml input data, return line by line particle data
#
def parseNuclei(filename):
    tree = ET.parse(filename)
    root = tree.getroot()

    for particle in root.iter("particle"):
        name = particle.attrib["name"]
        antiName = "Unknown"
        if ("antiName" in particle.attrib):
            antiName = particle.attrib["antiName"]
        pdg_id = int(particle.attrib["id"])
        A = int(particle.attrib["A"])
        Z = int(particle.attrib["Z"])
        # mass in GeV
        if ("mass" in particle.attrib):
            mass = particle.attrib["mass"]
        else:
            mass = (A-Z)*mneutron + Z*mproton

        electric_charge = Z*3  # in units of e/3
        ctau = float('Inf')

        yield (pdg_id, name, mass, electric_charge, antiName, ctau/c_speed_of_light, A, Z)


##############################################################
#
# returns dict with particle codes and class names
#
def read_class_names(filename):
    tree = ET.parse(filename)
    root = tree.getroot()

    map = {}

    for particle in root.iter("particle"):
        classname = None
        name = None
        if ("classname" in particle.attrib):
            classname = particle.attrib["classname"]
        if ("name" in particle.attrib):
            name = particle.attrib["name"]
        pdg_id = int(particle.attrib["pdgID"])
        map[pdg_id] = {"classname": classname, "name": name}

    return map

##############################################################
#
# Automatically produce a string qualifying as C++ class name
#
# This function produces names of type "DeltaPlusPlus"
#


def c_identifier_camel(name):
    orig = name
    name = name[0].upper() + name[1:].lower()  # all lower case

    for c in "() /":  # replace funny characters
        name = name.replace(c, "_")

    name = name.replace("bar", "Bar")
    name = name.replace("*", "Star")
    name = name.replace("'", "Prime")
    name = name.replace("+", "Plus")
    name = name.replace("-", "Minus")

    # move "Bar" to end of name
    ibar = name.find('Bar')
    if ibar > 0 and ibar < len(name)-3:
        name = name[:ibar] + name[ibar+3:] + 'Bar'

    # cleanup "_"s
    while True:
        tmp = name.replace("__", "_")
        if tmp == name:
            break
        else:
            name = tmp
    name.strip("_")

    # remove all "_", if this does not by accident concatenate two numbers
    istart = 0
    while True:
        i = name.find('_', istart)
        if i < 1 or i > len(name)-1:
            break
        istart = i
        if name[i-1].isdigit() and name[i+1].isdigit():
            # there is a number on both sides
            break
        name = name[:i] + name[i+1:]
        # and last, for example: make NuE out of Nue
        if name[i-1].islower() and name[i].islower():
            if i < len(name)-1:
                name = name[:i] + name[i].upper() + name[i+1:]
            else:
                name = name[:i] + name[i].upper()

    # check if name is valid C++ identifier
    pattern = re.compile(r'^[a-zA-Z_][a-zA-Z_0-9]*$')
    if pattern.match(name):
        return name
    else:
        raise Exception(
            "could not generate C identifier for '{:s}': result '{:s}'".format(orig, name))


##########################################################
#
# returns dict containing all data from pythia-xml input
#
def read_pythia_db(filename, particle_db, classnames):

    counter = itertools.count(len(particle_db))

    for (pdg, name, mass, electric_charge, antiName, lifetime) in parsePythia(filename):

        c_id = "Unknown"
        if pdg in classnames and classnames[pdg]["classname"] != None:
            c_id = classnames[pdg]["classname"]
        else:
            c_id = c_identifier_camel(name)  # the camel case names

        if pdg in classnames and classnames[pdg]["name"] != None:
            name = classnames[pdg]["name"]

        hadron = abs(pdg) > 100

        if c_id in particle_db.keys():
            raise RuntimeError("particle '{:s}' already known (new PDG id {:d}, stored PDG id: {:d})".format(
                c_id, pdg, particle_db[c_id]['pdg']))

        particle_db[c_id] = {
            "name": name,
            "antiName": antiName,
            "pdg": pdg,
            "mass": mass,  # in GeV
            "electric_charge": electric_charge,  # in e/3
            "lifetime": lifetime,
            "ngc_code": next(counter),
            "isNucleus": False,
            "isHadron": hadron,
        }

    return particle_db


##########################################################
#
# returns dict containing all data from pythia-xml input
#
def read_nuclei_db(filename, particle_db, classnames):

    counter = itertools.count(len(particle_db))

    for (pdg, name, mass, electric_charge, antiName, lifetime, A, Z) in parseNuclei(filename):

        c_id = "Unknown"
        if pdg in classnames and classnames[pdg]["classname"]:
            c_id = classnames[pdg]["classname"]
        else:
            c_id = c_identifier_camel(name)

        if pdg in classnames and classnames[pdg]["name"] != None:
            name = classnames[pdg]["name"]

        particle_db[c_id] = {
            "name": name,
            "antiName": antiName,
            "pdg": pdg,
            "mass": mass,  # in GeV
            "electric_charge": electric_charge,  # in e/3
            "lifetime": lifetime,
            "ngc_code": next(counter),
            "A": A,
            "Z": Z,
            "isNucleus": True,
            "isHadron": True,
        }

    return particle_db


###############################################################
#
# build conversion table PDG -> ngc
#
def gen_conversion_PDG_ngc(particle_db):
    # todo: find a optimum value, think about cache miss with array vs lookup time with map
    P_MAX = 500  # the maximum PDG code that is still filled into the table

    conversionDict = dict()
    conversionTable = [None] * (2*P_MAX + 1)
    for cId, p in particle_db.items():
        pdg = p['pdg']

        if abs(pdg) < P_MAX:
            if conversionTable[pdg + P_MAX]:
                raise Exception("table entry already occupied")
            else:
                conversionTable[pdg + P_MAX] = cId
        else:
            if pdg in conversionDict.keys():
                raise Exception(f"map entry {pdg} already occupied")
            else:
                conversionDict[pdg] = cId

    output = io.StringIO()

    def oprint(*args, **kwargs):
        print(*args, **kwargs, file=output)

    oprint(
        f"static std::array<Code, {len(conversionTable)}> constexpr conversionArray {{")
    for ngc in conversionTable:
        oprint("    Code::{0},".format(ngc if ngc else "Unknown"))
    oprint("};")
    oprint()

    oprint("static std::map<PDGCode, Code> const conversionMap {")
    for ngc in conversionDict.values():
        oprint(f"    {{PDGCode::{ngc}, Code::{ngc}}},")
    oprint("};")
    oprint()

    return output.getvalue()


###############################################################
#
# return string with enum of all internal particle codes
#
def gen_internal_enum(particle_db):
    string = ("//! @cond EXCLUDE_DOXY\n"
              "enum class Code : CodeIntType {\n"
              "  FirstParticle = 1, // if you want to loop over particles, you want to start with \"1\"  \n")  # identifier for eventual loops...

    for k in filter(lambda k: "ngc_code" in particle_db[k], particle_db):
        last_ngc_id = particle_db[k]['ngc_code']
        string += "  {key:s} = {code:d},\n".format(key=k, code=last_ngc_id)

    string += ("  LastParticle = {:d},\n"  # identifier for eventual loops...
               "}}; //! @endcond").format(last_ngc_id + 1)

    if last_ngc_id > 0x7fff:  # does not fit into int16_t
        raise Exception(
            "Integer overflow in internal particle code definition prevented!")

    return string


###############################################################
#
# return string with enum of all PDG particle codes
#
def gen_pdg_enum(particle_db):
    string = ("//! @cond EXCLUDE_DOXY\n"
              "enum class PDGCode : PDGCodeType {\n")

    for cId in particle_db:
        pdgCode = particle_db[cId]['pdg']
        string += "  {key:s} = {code:d},\n".format(key=cId, code=pdgCode)

    string += " }; //! @endcond \n"

    return string


###############################################################
#
# return string with all data arrays
#
def gen_properties(particle_db):

    # number of particles, size of tables
    string = "static constexpr std::size_t size = {size:d};\n".format(
        size=len(particle_db))
    string += "\n"

    # all particle initializer_list
    string += "constexpr std::initializer_list<Code> all_particles = {"
    for k in particle_db:
        string += "  Code::{name:s},\n".format(name=k)
    string += "};\n"
    string += "\n"

    # particle masses table
    string += "static constexpr std::array<corsika::units::si::HEPMassType const, size> masses = {\n"
    for p in particle_db.values():
        string += "  {mass:e} * 1e9 * corsika::units::si::electronvolt, // {name:s}\n".format(
            mass=p['mass'], name=p['name'])
    string += "};\n\n"

    # particle threshold table, initially set to 0
    string += "static std::array<corsika::units::si::HEPEnergyType, size> thresholds = {\n"    
    for k in particle_db:
        string += " 0 * corsika::units::si::electronvolt, // {name:s}\n".format( name = k)
    string += "};\n\n"

    # PDG code table
    string += "static constexpr std::array<PDGCode, size> pdg_codes = {\n"
    for p in particle_db.keys():
        string += f"  PDGCode::{p},\n"
    string += "};\n"

    # name string table
    string += "static constexpr std::array<std::string_view, size> names = {\n"
    for p in particle_db.values():
        string += "  \"{name:s}\",\n".format(name=p['name'])
    string += "};\n"

    # electric charges table
    string += "static constexpr std::array<int16_t, size> electric_charges = {\n"
    for p in particle_db.values():
        string += "  {charge:d},\n".format(charge=p['electric_charge'] // 3)
    string += "};\n"

    # anti-particle table
    #    string += "static constexpr std::array<size, size> anti_particle = {\n"
    #    for p in particle_db.values():
    #        string += "  {anti:d},\n".format(charge = p['anti_particle'])
    #    string += "};\n"

    # lifetime
    #string += "static constexpr std::array<corsika::units::si::TimeType const, size> lifetime = {\n"
    string += "static constexpr std::array<double const, size> lifetime = {\n"
    for p in particle_db.values():
        if p['lifetime'] == float("Inf"):
            # * corsika::units::si::second, \n"
            string += "  std::numeric_limits<double>::infinity(), \n"
        else:
            string += "  {tau:e}, \n".format(tau=p['lifetime'])
            #string += "  {tau:e} * corsika::units::si::second, \n".format(tau = p['lifetime'])
    string += "};\n"

    # is Hadron flag
    string += "static constexpr std::array<bool, size> isHadron = {\n"
    for p in particle_db.values():
        value = 'false'
        if p['isHadron']:
            value = 'true'
        string += "  {val},\n".format(val=value)
    string += "};\n"

    ### nuclear data ###

    # nucleus mass number A
    string += "static constexpr std::array<int16_t, size> nucleusA = {\n"
    for p in particle_db.values():
        A = p.get('A', 0)
        string += "  {val},\n".format(val=A)
    string += "};\n"

    # nucleus charge number Z
    string += "static constexpr std::array<int16_t, size> nucleusZ = {\n"
    for p in particle_db.values():
        Z = p.get('Z', 0)
        string += "  {val},\n".format(val=Z)
    string += "};\n"

    return string


###############################################################
#
# return string with a list of classes for all particles
#
def gen_classes(particle_db):

    string = ("// list of C++ classes to access particle properties\n"
              "/** @defgroup ParticleClasses \n"
              "    @{ */\n")

    for cname in particle_db:
        if cname == "Nucleus":
            string += "// skipping Nucleus"
            continue

        antiP = 'Unknown'
        for cname_anti in particle_db:
            if (particle_db[cname_anti]['name'] == particle_db[cname]['antiName']):
                antiP = cname_anti
                break

        string += "\n"
        string += "/** @class " + cname + "\n\n"
        string += " * Particle properties are taken from the PYTHIA8 ParticleData.xml file:<br>\n"
        string += " *  - pdg=" + str(particle_db[cname]['pdg']) + "\n"
        string += " *  - mass=" + str(particle_db[cname]['mass']) + " GeV \n"
        string += " *  - charge= " + \
            str(particle_db[cname]['electric_charge'] // 3) + " \n"
        string += " *  - name=" + str(cname) + "\n"
        string += " *  - anti=" + str(antiP) + "\n"
        if (particle_db[cname]['isNucleus']):
            string += " *  - nuclear A=" + str(particle_db[cname]['A']) + "\n"
            string += " *  - nuclear Z=" + str(particle_db[cname]['Z']) + "\n"
        string += "*/\n\n"
        string += "class " + cname + " {\n"
        string += "   /** @cond EXCLUDE_DOXY */ \n"
        string += "  public:\n"
        string += "   " + cname + "() = delete;\n"
        string += "   static constexpr Code code{Code::" + cname + "};\n"
        string += "   static constexpr Code anti_code{Code::" + antiP + "};\n"
        string += "   static constexpr HEPMassType mass{corsika::get_mass(code)};\n"
        string += "   static constexpr ElectricChargeType charge{corsika::get_charge(code)};\n"
        string += "   static constexpr int charge_number{corsika::get_charge_number(code)};\n"
        string += "   static constexpr std::string_view name{corsika::get_name(code)};\n"
        string += "   static constexpr bool is_nucleus{corsika::is_nucleus(code)};\n"
        if particle_db[cname]['isNucleus']:
            string += "   static constexpr int nucleus_A{corsika::get_nucleus_A(code)};\n"
            string += "   static constexpr int nucleus_Z{corsika::get_nucleus_Z(code)};\n"
        string += " private:\n"
        string += "   static constexpr CodeIntType TypeIndex = static_cast<CodeIntType>(code);\n"
        string += "   /** @endcond */ \n"
        string += "};\n"

    string += "  //! @}\n"

    return string


###############################################################
#
#
def inc_start():
    string = ('// generated by pdxml_reader.py\n'
              '// MANUAL EDITS ON OWN RISK. THEY WILL BE OVERWRITTEN. \n'
              '\n'
              'namespace corsika {\n'
              '/** @ingroup Particles \n'
              '    @{ \n'
              '  */ \n'
              )
    return string


###############################################################
#
#
def detail_start():
    string = ('/** @cond EXCLUDE_DOXY */\n'
              ' namespace particle::detail {\n\n')
    return string


###############################################################
#
#
def detail_end():
    string = "\n}//end namespace particle::detail\n /** @endcond */"
    return string

###############################################################
#
#


def inc_end():
    string = "/** @} */\n} // end namespace corsika"
    return string


###################################################################
#
# Serialize particle_db into file
#
def serialize_particle_db(particle_db, file):
    pickle.dump(particle_db, file)

# %%
names = read_class_names("pythia_data/ParticleClassNames.xml")
particle_db = OrderedDict()
read_pythia_db("pythia_data/ParticleData.xml", particle_db, names)
read_nuclei_db("pythia_data/NuclearData.xml", particle_db, names)
# Out:
# OrderedDict([('Unknown',
#               {'name': 'void',
#                'antiName': 'Unknown',
#                'pdg': 0,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': 0.0,
#                'ngc_code': 0,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('Electron',
#               {'name': 'e-',
#                'antiName': 'e+',
#                'pdg': 11,
#                'mass': 0.000511,
#                'electric_charge': -3,
#                'lifetime': inf,
#                'ngc_code': 1,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('Positron',
#               {'name': 'e+',
#                'antiName': 'e-',
#                'pdg': -11,
#                'mass': 0.000511,
#                'electric_charge': 3,
#                'lifetime': inf,
#                'ngc_code': 2,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuE',
#               {'name': 'nu_e',
#                'antiName': 'nu_ebar',
#                'pdg': 12,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 3,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuEBar',
#               {'name': 'nu_ebar',
#                'antiName': 'nu_e',
#                'pdg': -12,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 4,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('MuMinus',
#               {'name': 'mu-',
#                'antiName': 'mu+',
#                'pdg': 13,
#                'mass': 0.10566,
#                'electric_charge': -3,
#                'lifetime': 2.1970332555864364e-06,
#                'ngc_code': 5,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('MuPlus',
#               {'name': 'mu+',
#                'antiName': 'mu-',
#                'pdg': -13,
#                'mass': 0.10566,
#                'electric_charge': 3,
#                'lifetime': 2.1970332555864364e-06,
#                'ngc_code': 6,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuMu',
#               {'name': 'nu_mu',
#                'antiName': 'nu_mubar',
#                'pdg': 14,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 7,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuMuBar',
#               {'name': 'nu_mubar',
#                'antiName': 'nu_mu',
#                'pdg': -14,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 8,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('TauMinus',
#               {'name': 'tau-',
#                'antiName': 'tau+',
#                'pdg': 15,
#                'mass': 1.77682,
#                'electric_charge': -3,
#                'lifetime': 2.9056768332711026e-13,
#                'ngc_code': 9,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('TauPlus',
#               {'name': 'tau+',
#                'antiName': 'tau-',
#                'pdg': -15,
#                'mass': 1.77682,
#                'electric_charge': 3,
#                'lifetime': 2.9056768332711026e-13,
#                'ngc_code': 10,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuTau',
#               {'name': 'nu_tau',
#                'antiName': 'nu_taubar',
#                'pdg': 16,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 11,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('NuTauBar',
#               {'name': 'nu_taubar',
#                'antiName': 'nu_tau',
#                'pdg': -16,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 12,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('Photon',
#               {'name': 'photon',
#                'antiName': 'Unknown',
#                'pdg': 22,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 13,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('Z0',
#               {'name': 'Z0',
#                'antiName': 'Unknown',
#                'pdg': 23,
#                'mass': 91.1876,
#                'electric_charge': 0,
#                'lifetime': 2.6379123883107305e-25,
#                'ngc_code': 14,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('WPlus',
#               {'name': 'W+',
#                'antiName': 'W-',
#                'pdg': 24,
#                'mass': 80.385,
#                'electric_charge': 3,
#                'lifetime': 3.15689160254817e-25,
#                'ngc_code': 15,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('WMinus',
#               {'name': 'W-',
#                'antiName': 'W+',
#                'pdg': -24,
#                'mass': 80.385,
#                'electric_charge': -3,
#                'lifetime': 3.15689160254817e-25,
#                'ngc_code': 16,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('H0',
#               {'name': 'h0',
#                'antiName': 'Unknown',
#                'pdg': 25,
#                'mass': 125.0,
#                'electric_charge': 0,
#                'lifetime': 1.759924863987416e-22,
#                'ngc_code': 17,
#                'isNucleus': False,
#                'isHadron': False}),
#              ('Pi0',
#               {'name': 'pi0',
#                'antiName': 'Unknown',
#                'pdg': 111,
#                'mass': 0.13498,
#                'electric_charge': 0,
#                'lifetime': 8.51632498373258e-17,
#                'ngc_code': 18,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Rho0',
#               {'name': 'rho0',
#                'antiName': 'Unknown',
#                'pdg': 113,
#                'mass': 0.77549,
#                'electric_charge': 0,
#                'lifetime': 4.414566727909413e-24,
#                'ngc_code': 19,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('K0Long',
#               {'name': 'K_L0',
#                'antiName': 'Unknown',
#                'pdg': 130,
#                'mass': 0.49761,
#                'electric_charge': 0,
#                'lifetime': 5.113537579387671e-08,
#                'ngc_code': 20,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('PiPlus',
#               {'name': 'pi+',
#                'antiName': 'pi-',
#                'pdg': 211,
#                'mass': 0.13957,
#                'electric_charge': 3,
#                'lifetime': 2.6033009809739776e-08,
#                'ngc_code': 21,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('PiMinus',
#               {'name': 'pi-',
#                'antiName': 'pi+',
#                'pdg': -211,
#                'mass': 0.13957,
#                'electric_charge': -3,
#                'lifetime': 2.6033009809739776e-08,
#                'ngc_code': 22,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('RhoPlus',
#               {'name': 'rho+',
#                'antiName': 'rho-',
#                'pdg': 213,
#                'mass': 0.77549,
#                'electric_charge': 3,
#                'lifetime': 4.414566727909413e-24,
#                'ngc_code': 23,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('RhoMinus',
#               {'name': 'rho-',
#                'antiName': 'rho+',
#                'pdg': -213,
#                'mass': 0.77549,
#                'electric_charge': -3,
#                'lifetime': 4.414566727909413e-24,
#                'ngc_code': 24,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Pi1300Plus',
#               {'name': 'pi(1300)+',
#                'antiName': 'pi(1300)-',
#                'pdg': 100211,
#                'mass': 1.3,
#                'electric_charge': 3,
#                'lifetime': 3.291059495656467e-24,
#                'ngc_code': 25,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Pi1300Minus',
#               {'name': 'pi(1300)-',
#                'antiName': 'pi(1300)+',
#                'pdg': -100211,
#                'mass': 1.3,
#                'electric_charge': -3,
#                'lifetime': 3.291059495656467e-24,
#                'ngc_code': 26,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Pi1300_0',
#               {'name': 'pi(1300)0',
#                'antiName': 'Unknown',
#                'pdg': 100111,
#                'mass': 1.3,
#                'electric_charge': 3,
#                'lifetime': 3.291059495656467e-24,
#                'ngc_code': 27,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Eta',
#               {'name': 'eta',
#                'antiName': 'Unknown',
#                'pdg': 221,
#                'mass': 0.54785,
#                'electric_charge': 0,
#                'lifetime': 5.036817837492095e-19,
#                'ngc_code': 28,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Omega',
#               {'name': 'omega',
#                'antiName': 'Unknown',
#                'pdg': 223,
#                'mass': 0.78265,
#                'electric_charge': 0,
#                'lifetime': 7.752790331346213e-23,
#                'ngc_code': 29,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('K0Short',
#               {'name': 'K_S0',
#                'antiName': 'Unknown',
#                'pdg': 310,
#                'mass': 0.49761,
#                'electric_charge': 0,
#                'lifetime': 8.953527443308797e-11,
#                'ngc_code': 30,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('K0',
#               {'name': 'K0',
#                'antiName': 'Kbar0',
#                'pdg': 311,
#                'mass': 0.49761,
#                'electric_charge': 0,
#                'lifetime': 3.335640951981521e-27,
#                'ngc_code': 31,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('K0Bar',
#               {'name': 'Kbar0',
#                'antiName': 'K0',
#                'pdg': -311,
#                'mass': 0.49761,
#                'electric_charge': 0,
#                'lifetime': 3.335640951981521e-27,
#                'ngc_code': 32,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0',
#               {'name': 'K*0',
#                'antiName': 'K*bar0',
#                'pdg': 313,
#                'mass': 0.89594,
#                'electric_charge': 0,
#                'lifetime': 1.3515644746022452e-23,
#                'ngc_code': 33,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0Bar',
#               {'name': 'K*bar0',
#                'antiName': 'K*0',
#                'pdg': -313,
#                'mass': 0.89594,
#                'electric_charge': 0,
#                'lifetime': 1.3515644746022452e-23,
#                'ngc_code': 34,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0_1430_0',
#               {'name': 'K*0(1430)0',
#                'antiName': 'K*0(1430)0bar',
#                'pdg': 10311,
#                'mass': 1.425,
#                'electric_charge': 0,
#                'lifetime': 2.4378218486344205e-24,
#                'ngc_code': 35,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0_1430_0Bar',
#               {'name': 'K*0(1430)0bar',
#                'antiName': 'K*0(1430)0',
#                'pdg': -10311,
#                'mass': 1.425,
#                'electric_charge': 0,
#                'lifetime': 2.4378218486344205e-24,
#                'ngc_code': 36,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0_1430_Plus',
#               {'name': 'K*0(1430)+',
#                'antiName': 'K*0(1430)bar-',
#                'pdg': 10321,
#                'mass': 1.425,
#                'electric_charge': 0,
#                'lifetime': 2.4378218486344205e-24,
#                'ngc_code': 37,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStar0_1430_MinusBar',
#               {'name': 'K*0(1430)bar-',
#                'antiName': 'K*0(1430)+',
#                'pdg': -10321,
#                'mass': 1.425,
#                'electric_charge': 0,
#                'lifetime': 2.4378218486344205e-24,
#                'ngc_code': 38,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KPlus',
#               {'name': 'K+',
#                'antiName': 'K-',
#                'pdg': 321,
#                'mass': 0.49368,
#                'electric_charge': 3,
#                'lifetime': 1.2385234854707385e-08,
#                'ngc_code': 39,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KMinus',
#               {'name': 'K-',
#                'antiName': 'K+',
#                'pdg': -321,
#                'mass': 0.49368,
#                'electric_charge': -3,
#                'lifetime': 1.2385234854707385e-08,
#                'ngc_code': 40,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStarPlus',
#               {'name': 'K*+',
#                'antiName': 'K*-',
#                'pdg': 323,
#                'mass': 0.89166,
#                'electric_charge': 3,
#                'lifetime': 1.2956927148253809e-23,
#                'ngc_code': 41,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('KStarMinus',
#               {'name': 'K*-',
#                'antiName': 'K*+',
#                'pdg': -323,
#                'mass': 0.89166,
#                'electric_charge': -3,
#                'lifetime': 1.2956927148253809e-23,
#                'ngc_code': 42,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('EtaPrime',
#               {'name': "eta'",
#                'antiName': 'Unknown',
#                'pdg': 331,
#                'mass': 0.95778,
#                'electric_charge': 0,
#                'lifetime': 3.2910594956564672e-21,
#                'ngc_code': 43,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Phi',
#               {'name': 'phi',
#                'antiName': 'Unknown',
#                'pdg': 333,
#                'mass': 1.01946,
#                'electric_charge': 0,
#                'lifetime': 1.5450983547682947e-22,
#                'ngc_code': 44,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DPlus',
#               {'name': 'D+',
#                'antiName': 'D-',
#                'pdg': 411,
#                'mass': 1.86962,
#                'electric_charge': 3,
#                'lifetime': 1.0400528488278382e-12,
#                'ngc_code': 45,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DMinus',
#               {'name': 'D-',
#                'antiName': 'D+',
#                'pdg': -411,
#                'mass': 1.86962,
#                'electric_charge': -3,
#                'lifetime': 1.0400528488278382e-12,
#                'ngc_code': 46,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStarPlus',
#               {'name': 'D*+',
#                'antiName': 'D*-',
#                'pdg': 413,
#                'mass': 2.01028,
#                'electric_charge': 3,
#                'lifetime': 7.872112646676389e-21,
#                'ngc_code': 47,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStarMinus',
#               {'name': 'D*-',
#                'antiName': 'D*+',
#                'pdg': -413,
#                'mass': 2.01028,
#                'electric_charge': -3,
#                'lifetime': 7.872112646676389e-21,
#                'ngc_code': 48,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('D0',
#               {'name': 'D0',
#                'antiName': 'Dbar0',
#                'pdg': 421,
#                'mass': 1.86486,
#                'electric_charge': 0,
#                'lifetime': 4.0995027299852886e-13,
#                'ngc_code': 49,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('D0Bar',
#               {'name': 'Dbar0',
#                'antiName': 'D0',
#                'pdg': -421,
#                'mass': 1.86486,
#                'electric_charge': 0,
#                'lifetime': 4.0995027299852886e-13,
#                'ngc_code': 50,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStar0',
#               {'name': 'D*0',
#                'antiName': 'D*bar0',
#                'pdg': 423,
#                'mass': 2.00698,
#                'electric_charge': 0,
#                'lifetime': 0.0,
#                'ngc_code': 51,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStar0Bar',
#               {'name': 'D*bar0',
#                'antiName': 'D*0',
#                'pdg': -423,
#                'mass': 2.00698,
#                'electric_charge': 0,
#                'lifetime': 0.0,
#                'ngc_code': 52,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DsPlus',
#               {'name': 'D_s+',
#                'antiName': 'D_s-',
#                'pdg': 431,
#                'mass': 1.96849,
#                'electric_charge': 3,
#                'lifetime': 5.000125787020299e-13,
#                'ngc_code': 53,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DsMinus',
#               {'name': 'D_s-',
#                'antiName': 'D_s+',
#                'pdg': -431,
#                'mass': 1.96849,
#                'electric_charge': -3,
#                'lifetime': 5.000125787020299e-13,
#                'ngc_code': 54,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStarSPlus',
#               {'name': 'D*_s+',
#                'antiName': 'D*_s-',
#                'pdg': 433,
#                'mass': 2.1123,
#                'electric_charge': 3,
#                'lifetime': 0.0,
#                'ngc_code': 55,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DStarSMinus',
#               {'name': 'D*_s-',
#                'antiName': 'D*_s+',
#                'pdg': -433,
#                'mass': 2.1123,
#                'electric_charge': -3,
#                'lifetime': 0.0,
#                'ngc_code': 56,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('EtaC',
#               {'name': 'eta_c',
#                'antiName': 'Unknown',
#                'pdg': 441,
#                'mass': 2.981,
#                'electric_charge': 0,
#                'lifetime': 2.216201680576746e-23,
#                'ngc_code': 57,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Jpsi',
#               {'name': 'J/psi',
#                'antiName': 'Unknown',
#                'pdg': 443,
#                'mass': 3.09692,
#                'electric_charge': 0,
#                'lifetime': 7.313465545903262e-21,
#                'ngc_code': 58,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('B0',
#               {'name': 'B0',
#                'antiName': 'Bbar0',
#                'pdg': 511,
#                'mass': 5.27958,
#                'electric_charge': 0,
#                'lifetime': 1.5300585046739235e-12,
#                'ngc_code': 59,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('B0Bar',
#               {'name': 'Bbar0',
#                'antiName': 'B0',
#                'pdg': -511,
#                'mass': 5.27958,
#                'electric_charge': 0,
#                'lifetime': 1.5300585046739235e-12,
#                'ngc_code': 60,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('BPlus',
#               {'name': 'B+',
#                'antiName': 'B-',
#                'pdg': 521,
#                'mass': 5.27925,
#                'electric_charge': 3,
#                'lifetime': 1.6381332715181247e-12,
#                'ngc_code': 61,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('BMinus',
#               {'name': 'B-',
#                'antiName': 'B+',
#                'pdg': -521,
#                'mass': 5.27925,
#                'electric_charge': -3,
#                'lifetime': 1.6381332715181247e-12,
#                'ngc_code': 62,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Bs0',
#               {'name': 'B_s0',
#                'antiName': 'B_sbar0',
#                'pdg': 531,
#                'mass': 5.36677,
#                'electric_charge': 0,
#                'lifetime': 1.4643463779198874e-12,
#                'ngc_code': 63,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Bs0Bar',
#               {'name': 'B_sbar0',
#                'antiName': 'B_s0',
#                'pdg': -531,
#                'mass': 5.36677,
#                'electric_charge': 0,
#                'lifetime': 1.4643463779198874e-12,
#                'ngc_code': 64,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('BcPlus',
#               {'name': 'B_c+',
#                'antiName': 'B_c-',
#                'pdg': 541,
#                'mass': 6.277,
#                'electric_charge': 3,
#                'lifetime': 4.603184513734499e-13,
#                'ngc_code': 65,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('BcMinus',
#               {'name': 'B_c-',
#                'antiName': 'B_c+',
#                'pdg': -541,
#                'mass': 6.277,
#                'electric_charge': -3,
#                'lifetime': 4.603184513734499e-13,
#                'ngc_code': 66,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaMinus',
#               {'name': 'Delta-',
#                'antiName': 'Deltabar+',
#                'pdg': 1114,
#                'mass': 1.232,
#                'electric_charge': -3,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 67,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaPlusBar',
#               {'name': 'Deltabar+',
#                'antiName': 'Delta-',
#                'pdg': -1114,
#                'mass': 1.232,
#                'electric_charge': 3,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 68,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Neutron',
#               {'name': 'n0',
#                'antiName': 'nbar0',
#                'pdg': 2112,
#                'mass': 0.93957,
#                'electric_charge': 0,
#                'lifetime': 885.6126727510937,
#                'ngc_code': 69,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('AntiNeutron',
#               {'name': 'nbar0',
#                'antiName': 'n0',
#                'pdg': -2112,
#                'mass': 0.93957,
#                'electric_charge': 0,
#                'lifetime': 885.6126727510937,
#                'ngc_code': 70,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Delta0',
#               {'name': 'Delta0',
#                'antiName': 'Deltabar0',
#                'pdg': 2114,
#                'mass': 1.232,
#                'electric_charge': 0,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 71,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Delta0Bar',
#               {'name': 'Deltabar0',
#                'antiName': 'Delta0',
#                'pdg': -2114,
#                'mass': 1.232,
#                'electric_charge': 0,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 72,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Proton',
#               {'name': 'p+',
#                'antiName': 'pbar-',
#                'pdg': 2212,
#                'mass': 0.93827,
#                'electric_charge': 3,
#                'lifetime': inf,
#                'ngc_code': 73,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('AntiProton',
#               {'name': 'pbar-',
#                'antiName': 'p+',
#                'pdg': -2212,
#                'mass': 0.93827,
#                'electric_charge': -3,
#                'lifetime': inf,
#                'ngc_code': 74,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1440Plus',
#               {'name': 'N(1440)+',
#                'antiName': 'N(1440)bar-',
#                'pdg': 202212,
#                'mass': 1.44,
#                'electric_charge': 3,
#                'lifetime': 1.88060542608941e-24,
#                'ngc_code': 75,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1440MinusBar',
#               {'name': 'N(1440)bar-',
#                'antiName': 'N(1440)+',
#                'pdg': -202212,
#                'mass': 1.44,
#                'electric_charge': -3,
#                'lifetime': 1.88060542608941e-24,
#                'ngc_code': 76,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1440_0',
#               {'name': 'N(1440)0',
#                'antiName': 'N(1440)bar0',
#                'pdg': 202112,
#                'mass': 1.44,
#                'electric_charge': 3,
#                'lifetime': 1.88060542608941e-24,
#                'ngc_code': 77,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1440_0Bar',
#               {'name': 'N(1440)bar0',
#                'antiName': 'N(1440)0',
#                'pdg': -202112,
#                'mass': 1.44,
#                'electric_charge': -3,
#                'lifetime': 1.88060542608941e-24,
#                'ngc_code': 78,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1710Plus',
#               {'name': 'N(1710)+',
#                'antiName': 'N(1710)bar-',
#                'pdg': 212212,
#                'mass': 1.71,
#                'electric_charge': 3,
#                'lifetime': 6.582118991312934e-24,
#                'ngc_code': 79,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1710MinusBar',
#               {'name': 'N(1710)bar-',
#                'antiName': 'N(1710)+',
#                'pdg': -212212,
#                'mass': 1.71,
#                'electric_charge': -3,
#                'lifetime': 6.582118991312934e-24,
#                'ngc_code': 80,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1710_0',
#               {'name': 'N(1710)0',
#                'antiName': 'N(1710)bar0',
#                'pdg': 212112,
#                'mass': 1.71,
#                'electric_charge': 3,
#                'lifetime': 6.582118991312934e-24,
#                'ngc_code': 81,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('N1710_0Bar',
#               {'name': 'N(1710)bar0',
#                'antiName': 'N(1710)0',
#                'pdg': -212112,
#                'mass': 1.71,
#                'electric_charge': -3,
#                'lifetime': 6.582118991312934e-24,
#                'ngc_code': 82,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaPlus',
#               {'name': 'Delta+',
#                'antiName': 'Deltabar-',
#                'pdg': 2214,
#                'mass': 1.232,
#                'electric_charge': 3,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 83,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaMinusBar',
#               {'name': 'Deltabar-',
#                'antiName': 'Delta+',
#                'pdg': -2214,
#                'mass': 1.232,
#                'electric_charge': -3,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 84,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaPlusPlus',
#               {'name': 'Delta++',
#                'antiName': 'Deltabar--',
#                'pdg': 2224,
#                'mass': 1.232,
#                'electric_charge': 6,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 85,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('DeltaMinusMinusBar',
#               {'name': 'Deltabar--',
#                'antiName': 'Delta++',
#                'pdg': -2224,
#                'mass': 1.232,
#                'electric_charge': -6,
#                'lifetime': 5.625742727617893e-24,
#                'ngc_code': 86,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaMinus',
#               {'name': 'Sigma-',
#                'antiName': 'Sigmabar+',
#                'pdg': 3112,
#                'mass': 1.19745,
#                'electric_charge': -3,
#                'lifetime': 1.4790231981086063e-10,
#                'ngc_code': 87,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaPlusBar',
#               {'name': 'Sigmabar+',
#                'antiName': 'Sigma-',
#                'pdg': -3112,
#                'mass': 1.19745,
#                'electric_charge': 3,
#                'lifetime': 1.4790231981086063e-10,
#                'ngc_code': 88,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarMinus',
#               {'name': 'Sigma*-',
#                'antiName': 'Sigma*bar+',
#                'pdg': 3114,
#                'mass': 1.3872,
#                'electric_charge': -3,
#                'lifetime': 1.670588576475364e-23,
#                'ngc_code': 89,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarPlusBar',
#               {'name': 'Sigma*bar+',
#                'antiName': 'Sigma*-',
#                'pdg': -3114,
#                'mass': 1.3872,
#                'electric_charge': 3,
#                'lifetime': 1.670588576475364e-23,
#                'ngc_code': 90,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Lambda0',
#               {'name': 'Lambda0',
#                'antiName': 'Lambdabar0',
#                'pdg': 3122,
#                'mass': 1.11568,
#                'electric_charge': 0,
#                'lifetime': 2.63182071111342e-10,
#                'ngc_code': 91,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Lambda0Bar',
#               {'name': 'Lambdabar0',
#                'antiName': 'Lambda0',
#                'pdg': -3122,
#                'mass': 1.11568,
#                'electric_charge': 0,
#                'lifetime': 2.63182071111342e-10,
#                'ngc_code': 92,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Sigma0',
#               {'name': 'Sigma0',
#                'antiName': 'Sigmabar0',
#                'pdg': 3212,
#                'mass': 1.19264,
#                'electric_charge': 0,
#                'lifetime': 7.405122913398975e-20,
#                'ngc_code': 93,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Sigma0Bar',
#               {'name': 'Sigmabar0',
#                'antiName': 'Sigma0',
#                'pdg': -3212,
#                'mass': 1.19264,
#                'electric_charge': 0,
#                'lifetime': 7.405122913398975e-20,
#                'ngc_code': 94,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStar0',
#               {'name': 'Sigma*0',
#                'antiName': 'Sigma*bar0',
#                'pdg': 3214,
#                'mass': 1.3837,
#                'electric_charge': 0,
#                'lifetime': 1.8283663864758154e-23,
#                'ngc_code': 95,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStar0Bar',
#               {'name': 'Sigma*bar0',
#                'antiName': 'Sigma*0',
#                'pdg': -3214,
#                'mass': 1.3837,
#                'electric_charge': 0,
#                'lifetime': 1.8283663864758154e-23,
#                'ngc_code': 96,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaPlus',
#               {'name': 'Sigma+',
#                'antiName': 'Sigmabar-',
#                'pdg': 3222,
#                'mass': 1.18937,
#                'electric_charge': 3,
#                'lifetime': 8.018880848563575e-11,
#                'ngc_code': 97,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaMinusBar',
#               {'name': 'Sigmabar-',
#                'antiName': 'Sigma+',
#                'pdg': -3222,
#                'mass': 1.18937,
#                'electric_charge': -3,
#                'lifetime': 8.018880848563575e-11,
#                'ngc_code': 98,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarPlus',
#               {'name': 'Sigma*+',
#                'antiName': 'Sigma*bar-',
#                'pdg': 3224,
#                'mass': 1.3828,
#                'electric_charge': 3,
#                'lifetime': 1.8283663864758154e-23,
#                'ngc_code': 99,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarMinusBar',
#               {'name': 'Sigma*bar-',
#                'antiName': 'Sigma*+',
#                'pdg': -3224,
#                'mass': 1.3828,
#                'electric_charge': -3,
#                'lifetime': 1.8283663864758154e-23,
#                'ngc_code': 100,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiMinus',
#               {'name': 'Xi-',
#                'antiName': 'Xibar+',
#                'pdg': 3312,
#                'mass': 1.32171,
#                'electric_charge': -3,
#                'lifetime': 1.6377997074229267e-10,
#                'ngc_code': 101,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiPlusBar',
#               {'name': 'Xibar+',
#                'antiName': 'Xi-',
#                'pdg': -3312,
#                'mass': 1.32171,
#                'electric_charge': 3,
#                'lifetime': 1.6377997074229267e-10,
#                'ngc_code': 102,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarMinus',
#               {'name': 'Xi*-',
#                'antiName': 'Xi*bar+',
#                'pdg': 3314,
#                'mass': 1.535,
#                'electric_charge': -3,
#                'lifetime': 6.648605041730237e-23,
#                'ngc_code': 103,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarPlusBar',
#               {'name': 'Xi*bar+',
#                'antiName': 'Xi*-',
#                'pdg': -3314,
#                'mass': 1.535,
#                'electric_charge': 3,
#                'lifetime': 6.648605041730237e-23,
#                'ngc_code': 104,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Xi0',
#               {'name': 'Xi0',
#                'antiName': 'Xibar0',
#                'pdg': 3322,
#                'mass': 1.31486,
#                'electric_charge': 0,
#                'lifetime': 2.9053432691759043e-10,
#                'ngc_code': 105,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Xi0Bar',
#               {'name': 'Xibar0',
#                'antiName': 'Xi0',
#                'pdg': -3322,
#                'mass': 1.31486,
#                'electric_charge': 0,
#                'lifetime': 2.9053432691759043e-10,
#                'ngc_code': 106,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStar0',
#               {'name': 'Xi*0',
#                'antiName': 'Xi*bar0',
#                'pdg': 3324,
#                'mass': 1.5318,
#                'electric_charge': 0,
#                'lifetime': 7.233097792651576e-23,
#                'ngc_code': 107,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStar0Bar',
#               {'name': 'Xi*bar0',
#                'antiName': 'Xi*0',
#                'pdg': -3324,
#                'mass': 1.5318,
#                'electric_charge': 0,
#                'lifetime': 7.233097792651576e-23,
#                'ngc_code': 108,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaMinus',
#               {'name': 'Omega-',
#                'antiName': 'Omegabar+',
#                'pdg': 3334,
#                'mass': 1.67245,
#                'electric_charge': -3,
#                'lifetime': 8.209012382826521e-11,
#                'ngc_code': 109,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaPlusBar',
#               {'name': 'Omegabar+',
#                'antiName': 'Omega-',
#                'pdg': -3334,
#                'mass': 1.67245,
#                'electric_charge': 3,
#                'lifetime': 8.209012382826521e-11,
#                'ngc_code': 110,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaC0',
#               {'name': 'Sigma_c0',
#                'antiName': 'Sigma_cbar0',
#                'pdg': 4112,
#                'mass': 2.45374,
#                'electric_charge': 0,
#                'lifetime': 3.047277310793026e-22,
#                'ngc_code': 111,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaC0Bar',
#               {'name': 'Sigma_cbar0',
#                'antiName': 'Sigma_c0',
#                'pdg': -4112,
#                'mass': 2.45374,
#                'electric_charge': 0,
#                'lifetime': 3.047277310793026e-22,
#                'ngc_code': 112,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarC0',
#               {'name': 'Sigma*_c0',
#                'antiName': 'Sigma*_cbar0',
#                'pdg': 4114,
#                'mass': 2.5188,
#                'electric_charge': 0,
#                'lifetime': 4.539392407802024e-23,
#                'ngc_code': 113,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarC0Bar',
#               {'name': 'Sigma*_cbar0',
#                'antiName': 'Sigma*_c0',
#                'pdg': -4114,
#                'mass': 2.5188,
#                'electric_charge': 0,
#                'lifetime': 4.539392407802024e-23,
#                'ngc_code': 114,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('LambdaCPlus',
#               {'name': 'Lambda_c+',
#                'antiName': 'Lambda_cbar-',
#                'pdg': 4122,
#                'mass': 2.28646,
#                'electric_charge': 3,
#                'lifetime': 1.9980489302369308e-13,
#                'ngc_code': 115,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('LambdaCMinusBar',
#               {'name': 'Lambda_cbar-',
#                'antiName': 'Lambda_c+',
#                'pdg': -4122,
#                'mass': 2.28646,
#                'electric_charge': -3,
#                'lifetime': 1.9980489302369308e-13,
#                'ngc_code': 116,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiC0',
#               {'name': 'Xi_c0',
#                'antiName': 'Xi_cbar0',
#                'pdg': 4132,
#                'mass': 2.47088,
#                'electric_charge': 0,
#                'lifetime': 1.1207753598657908e-13,
#                'ngc_code': 117,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiC0Bar',
#               {'name': 'Xi_cbar0',
#                'antiName': 'Xi_c0',
#                'pdg': -4132,
#                'mass': 2.47088,
#                'electric_charge': 0,
#                'lifetime': 1.1207753598657908e-13,
#                'ngc_code': 118,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaCPlus',
#               {'name': 'Sigma_c+',
#                'antiName': 'Sigma_cbar-',
#                'pdg': 4212,
#                'mass': 2.4529,
#                'electric_charge': 3,
#                'lifetime': 2.9918722687786065e-22,
#                'ngc_code': 119,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaCMinusBar',
#               {'name': 'Sigma_cbar-',
#                'antiName': 'Sigma_c+',
#                'pdg': -4212,
#                'mass': 2.4529,
#                'electric_charge': -3,
#                'lifetime': 2.9918722687786065e-22,
#                'ngc_code': 120,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarCPlus',
#               {'name': 'Sigma*_c+',
#                'antiName': 'Sigma*_cbar-',
#                'pdg': 4214,
#                'mass': 2.5175,
#                'electric_charge': 3,
#                'lifetime': 4.246528381492216e-23,
#                'ngc_code': 121,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarCMinusBar',
#               {'name': 'Sigma*_cbar-',
#                'antiName': 'Sigma*_c+',
#                'pdg': -4214,
#                'mass': 2.5175,
#                'electric_charge': -3,
#                'lifetime': 4.246528381492216e-23,
#                'ngc_code': 122,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaCPlusPlus',
#               {'name': 'Sigma_c++',
#                'antiName': 'Sigma_cbar--',
#                'pdg': 4222,
#                'mass': 2.45398,
#                'electric_charge': 6,
#                'lifetime': 2.912442031554396e-22,
#                'ngc_code': 123,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaCMinusMinusBar',
#               {'name': 'Sigma_cbar--',
#                'antiName': 'Sigma_c++',
#                'pdg': -4222,
#                'mass': 2.45398,
#                'electric_charge': -6,
#                'lifetime': 2.912442031554396e-22,
#                'ngc_code': 124,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarCPlusPlus',
#               {'name': 'Sigma*_c++',
#                'antiName': 'Sigma*_cbar--',
#                'pdg': 4224,
#                'mass': 2.5179,
#                'electric_charge': 6,
#                'lifetime': 4.417529524371097e-23,
#                'ngc_code': 125,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaStarCMinusMinusBar',
#               {'name': 'Sigma*_cbar--',
#                'antiName': 'Sigma*_c++',
#                'pdg': -4224,
#                'mass': 2.5179,
#                'electric_charge': -6,
#                'lifetime': 4.417529524371097e-23,
#                'ngc_code': 126,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiCPlus',
#               {'name': 'Xi_c+',
#                'antiName': 'Xi_cbar-',
#                'pdg': 4232,
#                'mass': 2.4678,
#                'electric_charge': 3,
#                'lifetime': 4.4030460566156074e-13,
#                'ngc_code': 127,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiCMinusBar',
#               {'name': 'Xi_cbar-',
#                'antiName': 'Xi_c+',
#                'pdg': -4232,
#                'mass': 2.4678,
#                'electric_charge': -3,
#                'lifetime': 4.4030460566156074e-13,
#                'ngc_code': 128,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiPrimeC0',
#               {'name': "Xi'_c0",
#                'antiName': "Xi'_cbar0",
#                'pdg': 4312,
#                'mass': 2.5779,
#                'electric_charge': 0,
#                'lifetime': 0.0,
#                'ngc_code': 129,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiPrimeC0Bar',
#               {'name': "Xi'_cbar0",
#                'antiName': "Xi'_c0",
#                'pdg': -4312,
#                'mass': 2.5779,
#                'electric_charge': 0,
#                'lifetime': 0.0,
#                'ngc_code': 130,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarC0',
#               {'name': 'Xi*_c0',
#                'antiName': 'Xi*_cbar0',
#                'pdg': 4314,
#                'mass': 2.6459,
#                'electric_charge': 0,
#                'lifetime': 2.531584227428052e-22,
#                'ngc_code': 131,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarC0Bar',
#               {'name': 'Xi*_cbar0',
#                'antiName': 'Xi*_c0',
#                'pdg': -4314,
#                'mass': 2.6459,
#                'electric_charge': 0,
#                'lifetime': 2.531584227428052e-22,
#                'ngc_code': 132,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiPrimeCPlus',
#               {'name': "Xi'_c+",
#                'antiName': "Xi'_cbar-",
#                'pdg': 4322,
#                'mass': 2.5756,
#                'electric_charge': 3,
#                'lifetime': 0.0,
#                'ngc_code': 133,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiPrimeCMinusBar',
#               {'name': "Xi'_cbar-",
#                'antiName': "Xi'_c+",
#                'pdg': -4322,
#                'mass': 2.5756,
#                'electric_charge': -3,
#                'lifetime': 0.0,
#                'ngc_code': 134,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarCPlus',
#               {'name': 'Xi*_c+',
#                'antiName': 'Xi*_cbar-',
#                'pdg': 4324,
#                'mass': 2.6459,
#                'electric_charge': 3,
#                'lifetime': 2.531584227428052e-22,
#                'ngc_code': 135,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiStarCMinusBar',
#               {'name': 'Xi*_cbar-',
#                'antiName': 'Xi*_c+',
#                'pdg': -4324,
#                'mass': 2.6459,
#                'electric_charge': -3,
#                'lifetime': 2.531584227428052e-22,
#                'ngc_code': 136,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaC0',
#               {'name': 'Omega_c0',
#                'antiName': 'Omega_cbar0',
#                'pdg': 4332,
#                'mass': 2.6952,
#                'electric_charge': 0,
#                'lifetime': 7.004845999161194e-14,
#                'ngc_code': 137,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaC0Bar',
#               {'name': 'Omega_cbar0',
#                'antiName': 'Omega_c0',
#                'pdg': -4332,
#                'mass': 2.6952,
#                'electric_charge': 0,
#                'lifetime': 7.004845999161194e-14,
#                'ngc_code': 138,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaBMinus',
#               {'name': 'Sigma_b-',
#                'antiName': 'Sigma_bbar+',
#                'pdg': 5112,
#                'mass': 5.8155,
#                'electric_charge': -3,
#                'lifetime': 0.0,
#                'ngc_code': 139,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaBPlusBar',
#               {'name': 'Sigma_bbar+',
#                'antiName': 'Sigma_b-',
#                'pdg': -5112,
#                'mass': 5.8155,
#                'electric_charge': 3,
#                'lifetime': 0.0,
#                'ngc_code': 140,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('LambdaB0',
#               {'name': 'Lambda_b0',
#                'antiName': 'Lambda_bbar0',
#                'pdg': 5122,
#                'mass': 5.6194,
#                'electric_charge': 0,
#                'lifetime': 1.230851511281181e-12,
#                'ngc_code': 141,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('LambdaB0Bar',
#               {'name': 'Lambda_bbar0',
#                'antiName': 'Lambda_b0',
#                'pdg': -5122,
#                'mass': 5.6194,
#                'electric_charge': 0,
#                'lifetime': 1.230851511281181e-12,
#                'ngc_code': 142,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiBMinus',
#               {'name': 'Xi_b-',
#                'antiName': 'Xi_bbar+',
#                'pdg': 5132,
#                'mass': 5.7911,
#                'electric_charge': -3,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 143,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiBPlusBar',
#               {'name': 'Xi_bbar+',
#                'antiName': 'Xi_b-',
#                'pdg': -5132,
#                'mass': 5.7911,
#                'electric_charge': 3,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 144,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaBPlus',
#               {'name': 'Sigma_b+',
#                'antiName': 'Sigma_bbar-',
#                'pdg': 5222,
#                'mass': 5.8113,
#                'electric_charge': 3,
#                'lifetime': 0.0,
#                'ngc_code': 145,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('SigmaBMinusBar',
#               {'name': 'Sigma_bbar-',
#                'antiName': 'Sigma_b+',
#                'pdg': -5222,
#                'mass': 5.8113,
#                'electric_charge': -3,
#                'lifetime': 0.0,
#                'ngc_code': 146,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiB0',
#               {'name': 'Xi_b0',
#                'antiName': 'Xi_bbar0',
#                'pdg': 5232,
#                'mass': 5.788,
#                'electric_charge': 0,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 147,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('XiB0Bar',
#               {'name': 'Xi_bbar0',
#                'antiName': 'Xi_b0',
#                'pdg': -5232,
#                'mass': 5.788,
#                'electric_charge': 0,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 148,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaBMinus',
#               {'name': 'Omega_b-',
#                'antiName': 'Omega_bbar+',
#                'pdg': 5332,
#                'mass': 6.07,
#                'electric_charge': -3,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 149,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('OmegaBPlusBar',
#               {'name': 'Omega_bbar+',
#                'antiName': 'Omega_b-',
#                'pdg': -5332,
#                'mass': 6.07,
#                'electric_charge': 3,
#                'lifetime': 1.2141733065212734e-12,
#                'ngc_code': 150,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Lambda1405_0',
#               {'name': 'Lambda(1405)0',
#                'antiName': 'Lambda(1405)bar0',
#                'pdg': 13122,
#                'mass': 1.4051,
#                'electric_charge': 0,
#                'lifetime': 1.3164237982625868e-23,
#                'ngc_code': 151,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Lambda1405_0Bar',
#               {'name': 'Lambda(1405)bar0',
#                'antiName': 'Lambda(1405)0',
#                'pdg': -13122,
#                'mass': 1.4051,
#                'electric_charge': 0,
#                'lifetime': 1.3164237982625868e-23,
#                'ngc_code': 152,
#                'isNucleus': False,
#                'isHadron': True}),
#              ('Nucleus',
#               {'name': 'nucleus',
#                'antiName': 'Unknown',
#                'pdg': 1000000000,
#                'mass': 0.0,
#                'electric_charge': 0,
#                'lifetime': inf,
#                'ngc_code': 153,
#                'A': 0,
#                'Z': 0,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Hydrogen',
#               {'name': 'hydrogen',
#                'antiName': 'Unknown',
#                'pdg': 1000010010,
#                'mass': 0.9382720813,
#                'electric_charge': 3,
#                'lifetime': inf,
#                'ngc_code': 154,
#                'A': 1,
#                'Z': 1,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Deuterium',
#               {'name': 'deuterium',
#                'antiName': 'Unknown',
#                'pdg': 1000010020,
#                'mass': 1.8778374946,
#                'electric_charge': 3,
#                'lifetime': inf,
#                'ngc_code': 155,
#                'A': 2,
#                'Z': 1,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Tritium',
#               {'name': 'tritium',
#                'antiName': 'Unknown',
#                'pdg': 1000010030,
#                'mass': 2.8174029079,
#                'electric_charge': 3,
#                'lifetime': inf,
#                'ngc_code': 156,
#                'A': 3,
#                'Z': 1,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Helium',
#               {'name': 'helium',
#                'antiName': 'Unknown',
#                'pdg': 1000020040,
#                'mass': 3.7556749892,
#                'electric_charge': 6,
#                'lifetime': inf,
#                'ngc_code': 157,
#                'A': 4,
#                'Z': 2,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Helium3',
#               {'name': 'helium3',
#                'antiName': 'Unknown',
#                'pdg': 1000020030,
#                'mass': 2.8161095758999997,
#                'electric_charge': 6,
#                'lifetime': inf,
#                'ngc_code': 158,
#                'A': 3,
#                'Z': 2,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Lithium7',
#               {'name': 'lithium7',
#                'antiName': 'Unknown',
#                'pdg': 1000030070,
#                'mass': 6.573077897099999,
#                'electric_charge': 9,
#                'lifetime': inf,
#                'ngc_code': 159,
#                'A': 7,
#                'Z': 3,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Beryllium9',
#               {'name': 'beryllium9',
#                'antiName': 'Unknown',
#                'pdg': 1000040090,
#                'mass': 8.4509153917,
#                'electric_charge': 12,
#                'lifetime': inf,
#                'ngc_code': 160,
#                'A': 9,
#                'Z': 4,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Boron11',
#               {'name': 'boron11',
#                'antiName': 'Unknown',
#                'pdg': 1000110050,
#                'mass': 10.328752886299998,
#                'electric_charge': 15,
#                'lifetime': inf,
#                'ngc_code': 161,
#                'A': 11,
#                'Z': 5,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Carbon',
#               {'name': 'carbon',
#                'antiName': 'Unknown',
#                'pdg': 1000060120,
#                'mass': 11.2670249676,
#                'electric_charge': 18,
#                'lifetime': inf,
#                'ngc_code': 162,
#                'A': 12,
#                'Z': 6,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Carbon13',
#               {'name': 'carbon13',
#                'antiName': 'Unknown',
#                'pdg': 1000060130,
#                'mass': 12.2065903809,
#                'electric_charge': 18,
#                'lifetime': inf,
#                'ngc_code': 163,
#                'A': 13,
#                'Z': 6,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Nitrogen',
#               {'name': 'nitrogen',
#                'antiName': 'Unknown',
#                'pdg': 1000070140,
#                'mass': 13.144862462199999,
#                'electric_charge': 21,
#                'lifetime': inf,
#                'ngc_code': 164,
#                'A': 14,
#                'Z': 7,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Oxygen',
#               {'name': 'oxygen',
#                'antiName': 'Unknown',
#                'pdg': 1000080160,
#                'mass': 15.0226999568,
#                'electric_charge': 24,
#                'lifetime': inf,
#                'ngc_code': 165,
#                'A': 16,
#                'Z': 8,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Fluor',
#               {'name': 'fluor',
#                'antiName': 'Unknown',
#                'pdg': 1000080180,
#                'mass': 16.900537451399998,
#                'electric_charge': 27,
#                'lifetime': inf,
#                'ngc_code': 166,
#                'A': 18,
#                'Z': 9,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Neon21',
#               {'name': 'neon21',
#                'antiName': 'Unknown',
#                'pdg': 1000100210,
#                'mass': 19.717940359299998,
#                'electric_charge': 30,
#                'lifetime': inf,
#                'ngc_code': 167,
#                'A': 21,
#                'Z': 10,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Neon',
#               {'name': 'neon',
#                'antiName': 'Unknown',
#                'pdg': 1000100220,
#                'mass': 20.657505772599997,
#                'electric_charge': 30,
#                'lifetime': inf,
#                'ngc_code': 168,
#                'A': 22,
#                'Z': 10,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Sulphur',
#               {'name': 'sulphur',
#                'antiName': 'Unknown',
#                'pdg': 1000160330,
#                'mass': 30.9849653269,
#                'electric_charge': 48,
#                'lifetime': inf,
#                'ngc_code': 169,
#                'A': 33,
#                'Z': 16,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Argon',
#               {'name': 'argon',
#                'antiName': 'Unknown',
#                'pdg': 1000180400,
#                'mass': 37.559336556,
#                'electric_charge': 54,
#                'lifetime': inf,
#                'ngc_code': 170,
#                'A': 40,
#                'Z': 18,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Iron',
#               {'name': 'iron',
#                'antiName': 'Unknown',
#                'pdg': 1000280560,
#                'mass': 52.579449848799996,
#                'electric_charge': 84,
#                'lifetime': inf,
#                'ngc_code': 171,
#                'A': 56,
#                'Z': 28,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Xenon',
#               {'name': 'xenon',
#                'antiName': 'Unknown',
#                'pdg': 1000541280,
#                'mass': 120.19453297439999,
#                'electric_charge': 162,
#                'lifetime': inf,
#                'ngc_code': 172,
#                'A': 128,
#                'Z': 54,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Lead',
#               {'name': 'lead',
#                'antiName': 'Unknown',
#                'pdg': 1000822080,
#                'mass': 195.32355274239998,
#                'electric_charge': 246,
#                'lifetime': inf,
#                'ngc_code': 173,
#                'A': 208,
#                'Z': 82,
#                'isNucleus': True,
#                'isHadron': True}),
#              ('Radon',
#               {'name': 'radon',
#                'antiName': 'Unknown',
#                'pdg': 1000862220,
#                'mass': 208.4722952006,
#                'electric_charge': 258,
#                'lifetime': inf,
#                'ngc_code': 174,
#                'A': 222,
#                'Z': 86,
#                'isNucleus': True,
#                'isHadron': True})])

# %%
chargeHadronIds=set()
for p in particle_db.values():
    if p["electric_charge"]!=0:
        chargeHadronIds.add(p["pdg"])

# %%
chargeHadronId_old = {211, 213, 9000211, 10213, 20213, 100211, 215, 9000213, 10211, 100213, 9010213, 10215,
 217, 30213, 9010211, 219, 321, 323, 10323, 20323, 100323, 10321, 325, 30323, 10325, 327, 20325, 329, 2212,
  12212, 2124, 22212, 32212, 2216, 12216, 22124, 42212, 32124, 2128, 1114, 2214, 2224, 31114, 32214, 32224,
   1112, 2122, 2222, 11114, 12214, 12224, 1116, 2126, 2226, 21112, 22122, 22222, 21114, 22214, 22224, 11116,
    12126, 12226, 1118, 2218, 2228, 3222, 3112, 3114, 3224, 13112, 13222, 13114, 13224, 23112, 23222, 3116,
     3226, 13116, 13226, 23114, 23224, 3118, 3228, 3312, 3314, 203312, 13314, 103316, 203316, 3334, 203338,
     -211, -213, -9000211, -10213, -20213, -100211, -215, -9000213, -10211, -100213, -9010213, -10215, -217,
     -30213, -9010211, -219, -321, -323, -10323, -20323, -100323, -10321, -325, -30323, -10325, -327, -20325,
      -329, -2212, -12212, -2124, -22212, -32212, -2216, -12216, -22124, -42212, -32124, -2128, -1114, -2214,
       -2224, -31114, -32214, -32224, -1112, -2122, -2222, -11114, -12214, -12224, -1116, -2126, -2226, -21112,
        -22122, -22222, -21114, -22214, -22224, -11116, -12126, -12226, -1118, -2218, -2228, -3222, -3112, -3114,
         -3224, -13112, -13222, -13114, -13224, -23112, -23222, -3116, -3226, -13116, -13226, -23114, -23224, -3118,
          -3228, -3312, -3314, -203312, -13314, -103316, -203316, -3334, -203338,
          411,-411,413,-413, 521,-521,523,-523}

# %%
chargeHadronIds.difference(chargeHadronId_old)
# Out:
# {-212212,
#  -212112,
#  -202212,
#  -202112,
#  -5332,
#  -5222,
#  -5132,
#  -5112,
#  -4324,
#  -4322,
#  -4232,
#  -4224,
#  -4222,
#  -4214,
#  -4212,
#  -4122,
#  -541,
#  -433,
#  -431,
#  -24,
#  -15,
#  -13,
#  -11,
#  11,
#  13,
#  15,
#  24,
#  431,
#  433,
#  541,
#  4122,
#  4212,
#  4214,
#  4222,
#  4224,
#  4232,
#  4322,
#  4324,
#  5112,
#  5132,
#  5222,
#  5332,
#  100111,
#  202112,
#  202212,
#  212112,
#  212212,
#  1000010010,
#  1000010020,
#  1000010030,
#  1000020030,
#  1000020040,
#  1000030070,
#  1000040090,
#  1000060120,
#  1000060130,
#  1000070140,
#  1000080160,
#  1000080180,
#  1000100210,
#  1000100220,
#  1000110050,
#  1000160330,
#  1000180400,
#  1000280560,
#  1000541280,
#  1000822080,
#  1000862220}
